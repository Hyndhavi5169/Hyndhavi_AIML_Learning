# %% [markdown]
# Hardware : where we can see the object with eyes, touch and feel physically. Examples: Keyboard, Monitor, Mouse and CPU
#
# Software : instructions to hardware components what action need to be taken when click action made to hadware object.
# Examples : Windows, Chrome, ZOOM, Whatsapp
